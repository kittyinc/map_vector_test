# %% [markdown]
# <a href="https://colab.research.google.com/github/psheljorde/map_vector_test/blob/main/test_random_map_vector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
from os import getcwd

print(getcwd())

img = plt.imread("sample_data/test_map.png")

fig, ax = plt.subplots()
x = range(1000)
y = range(1000)
ax.imshow(img, extent=[0, 1000, 0, 1000])
ax.plot(x, y, '--', linewidth=5, color='firebrick')
# Out:
# /content
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-6a0521353205> in <module>()
#      10 y = range(100)
#      11 ax.imshow(img, extent=[0, 1000, 0, 1000])
# ---> 12 ax.plot(x, y, '--', linewidth=5, color='firebrick')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
# ...
